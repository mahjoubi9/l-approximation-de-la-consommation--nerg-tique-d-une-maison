# %%
import numpy as np
import matplotlib.pylab as plt

# Import sklearn
from sklearn.preprocessing import LabelBinarizer
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report
from sklearn.preprocessing import scale
from sklearn import datasets

# %%
import os
from fnmatch import fnmatch
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from sklearn.model_selection import train_test_split,KFold
from sklearn import preprocessing
import seaborn as sns
from sklearn.metrics import confusion_matrix,classification_report
# %matplotlib inline
from sklearn.svm import SVC
import warnings
warnings.filterwarnings('ignore')

# %%
df_Energy=pd.read_csv('energydata_complete.csv')
df_Energy.head(3)
# Out:
#                   date  Appliances  lights     T1       RH_1    T2       RH_2  \
# 0  2016-01-11 17:00:00          60      30  19.89  47.596667  19.2  44.790000
# 1  2016-01-11 17:10:00          60      30  19.89  46.693333  19.2  44.722500
# 2  2016-01-11 17:20:00          50      30  19.89  46.300000  19.2  44.626667
#
#       T3       RH_3         T4  ...         T9   RH_9     T_out  Press_mm_hg  \
# 0  19.79  44.730000  19.000000  ...  17.033333  45.53  6.600000        733.5
# 1  19.79  44.790000  19.000000  ...  17.066667  45.56  6.483333        733.6
# 2  19.79  44.933333  18.926667  ...  17.000000  45.50  6.366667        733.7
#
#    RH_out  Windspeed  Visibility  Tdewpoint        rv1        rv2
# 0    92.0   7.000000   63.000000        5.3  13.275433  13.275433
# 1    92.0   6.666667   59.166667        5.2  18.606195  18.606195
# 2    92.0   6.333333   55.333333        5.1  28.642668  28.642668
#
# [3 rows x 29 columns]

# %%
#Check for Missing Value

df_Energy.isnull().sum()
# Out:
# date           0
# Appliances     0
# lights         0
# T1             0
# RH_1           0
# T2             0
# RH_2           0
# T3             0
# RH_3           0
# T4             0
# RH_4           0
# T5             0
# RH_5           0
# T6             0
# RH_6           0
# T7             0
# RH_7           0
# T8             0
# RH_8           0
# T9             0
# RH_9           0
# T_out          0
# Press_mm_hg    0
# RH_out         0
# Windspeed      0
# Visibility     0
# Tdewpoint      0
# rv1            0
# rv2            0
# dtype: int64

# %%
df_Energy.describe()
# Out:
#          Appliances        lights            T1          RH_1            T2  \
# count  19735.000000  19735.000000  19735.000000  19735.000000  19735.000000
# mean      97.694958      3.801875     21.686571     40.259739     20.341219
# std      102.524891      7.935988      1.606066      3.979299      2.192974
# min       10.000000      0.000000     16.790000     27.023333     16.100000
# 25%       50.000000      0.000000     20.760000     37.333333     18.790000
# 50%       60.000000      0.000000     21.600000     39.656667     20.000000
# 75%      100.000000      0.000000     22.600000     43.066667     21.500000
# max     1080.000000     70.000000     26.260000     63.360000     29.856667
#
#                RH_2            T3          RH_3            T4          RH_4  \
# count  19735.000000  19735.000000  19735.000000  19735.000000  19735.000000
# mean      40.420420     22.267611     39.242500     20.855335     39.026904
# std        4.069813      2.006111      3.254576      2.042884      4.341321
# min       20.463333     17.200000     28.766667     15.100000     27.660000
# 25%       37.900000     20.790000     36.900000     19.530000     35.530000
# 50%       40.500000     22.100000     38.530000     20.666667     38.400000
# 75%       43.260000     23.290000     41.760000     22.100000     42.156667
# max       56.026667     29.236000     50.163333     26.200000     51.090000
#
#        ...            T9          RH_9         T_out   Press_mm_hg  \
# count  ...  19735.000000  19735.000000  19735.000000  19735.000000
# mean   ...     19.485828     41.552401      7.411665    755.522602
# std    ...      2.014712      4.151497      5.317409      7.399441
# min    ...     14.890000     29.166667     -5.000000    729.300000
# 25%    ...     18.000000     38.500000      3.666667    750.933333
# 50%    ...     19.390000     40.900000      6.916667    756.100000
# 75%    ...     20.600000     44.338095     10.408333    760.933333
# max    ...     24.500000     53.326667     26.100000    772.300000
#
#              RH_out     Windspeed    Visibility     Tdewpoint           rv1  \
# count  19735.000000  19735.000000  19735.000000  19735.000000  19735.000000
# mean      79.750418      4.039752     38.330834      3.760707     24.988033
# std       14.901088      2.451221     11.794719      4.194648     14.496634
# min       24.000000      0.000000      1.000000     -6.600000      0.005322
# 25%       70.333333      2.000000     29.000000      0.900000     12.497889
# 50%       83.666667      3.666667     40.000000      3.433333     24.897653
# 75%       91.666667      5.500000     40.000000      6.566667     37.583769
# max      100.000000     14.000000     66.000000     15.500000     49.996530
#
#                 rv2
# count  19735.000000
# mean      24.988033
# std       14.496634
# min        0.005322
# 25%       12.497889
# 50%       24.897653
# 75%       37.583769
# max       49.996530
#
# [8 rows x 28 columns]

# %%
#Correlation:

fig = plt.figure(figsize=(28,20))

axis = sns.heatmap(df_Energy.corr(), cmap= 'YlOrRd', linewidth=1, linecolor='white', annot=True)
axis.set_title('Heatmap of Variables', fontsize=20)
# Out:
# Text(0.5, 1.0, 'Heatmap of Variables')

# %%
corr_matrix = df_Energy.corr().abs()

#the matrix is symmetric so we need to extract upper triangle matrix without diagonal (k = 1)

sol = (corr_matrix.where(np.triu(np.ones(corr_matrix.shape), k=1).astype(np.bool))
                 .stack()
                 .sort_values(ascending=False))
sol = sol.to_frame()
sol.columns=['corr']
sol[sol['corr'] >  0.88]
# Out:
#                 corr
# rv1  rv2    1.000000
# T6   T_out  0.974787
# T7   T9     0.944776
# T5   T9     0.911055
# T3   T9     0.901324
# RH_3 RH_4   0.898978
# RH_4 RH_7   0.894301
# T1   T3     0.892402
# T4   T9     0.889439
# T3   T5     0.888169
# T1   T5     0.885247
# RH_7 RH_8   0.883984
# T7   T8     0.882123
# RH_1 RH_4   0.880359

# %%
df_Energy.columns
# Out:
# Index(['date', 'Appliances', 'lights', 'T1', 'RH_1', 'T2', 'RH_2', 'T3',
#        'RH_3', 'T4', 'RH_4', 'T5', 'RH_5', 'T6', 'RH_6', 'T7', 'RH_7', 'T8',
#        'RH_8', 'T9', 'RH_9', 'T_out', 'Press_mm_hg', 'RH_out', 'Windspeed',
#        'Visibility', 'Tdewpoint', 'rv1', 'rv2'],
#       dtype='object')

# %%
df_final = df_Energy[['T1', 
                     'T2', 
                     'RH_1', 
                     'RH_2',
                     'RH_6', 
                     'T_out',
                     'lights',
                     'Windspeed',
                     'RH_out', 
                     'Appliances',
                     'Press_mm_hg',
                     'rv1',
                     'Tdewpoint']]

df_final['Appliances_Energy'] = np.where(df_final['Appliances']>= 60, 1, 0)
df_final.drop(columns=['Appliances'],axis=1,inplace=True)

# %%
df_final.head()
# Out:
#       T1    T2       RH_1       RH_2       RH_6     T_out  lights  Windspeed  \
# 0  19.89  19.2  47.596667  44.790000  84.256667  6.600000      30   7.000000
# 1  19.89  19.2  46.693333  44.722500  84.063333  6.483333      30   6.666667
# 2  19.89  19.2  46.300000  44.626667  83.156667  6.366667      30   6.333333
# 3  19.89  19.2  46.066667  44.590000  83.423333  6.250000      40   6.000000
# 4  19.89  19.2  46.333333  44.530000  84.893333  6.133333      40   5.666667
#
#    RH_out  Press_mm_hg        rv1  Tdewpoint  Appliances_Energy
# 0    92.0        733.5  13.275433        5.3                  1
# 1    92.0        733.6  18.606195        5.2                  1
# 2    92.0        733.7  28.642668        5.1                  0
# 3    92.0        733.8  45.410389        5.0                  0
# 4    92.0        733.9  10.084097        4.9                  1

# %%
fig = plt.figure(figsize=(28,20))

axis = sns.heatmap(df_final.corr(), cmap= 'YlOrRd', linewidth=1, linecolor='white', annot=True)
axis.set_title('Heatmap of Variables', fontsize=20)
# Out:
# Text(0.5, 1.0, 'Heatmap of Variables')

# %%
x = df_final.drop(columns=['Appliances_Energy'],axis=1)

y = df_final[['Appliances_Energy']]

xTrain, xTest, yTrain, yTest = train_test_split(x,y, test_size = 0.3, random_state = 0)

# %%
print('Shape of xTrain Set', xTrain.shape)
print('Shape of yTrain Set', yTrain.shape)

print('')

print('Shape of xTest Set', xTest.shape)
print('Shape of yTest Set', yTest.shape)
# Out:
# Shape of xTrain Set (13814, 12)
# Shape of yTrain Set (13814, 1)
#
# Shape of xTest Set (5921, 12)
# Shape of yTest Set (5921, 1)

# %%
cv=KFold(n_splits=10)

for train_index, test_index in cv.split(x):
    xTrain_cv,xTest_cv=x.iloc[train_index],x.iloc[test_index]
    yTrain_cv,yTest_cv=y.iloc[train_index],y.iloc[test_index]
    
print('Shape of xTrain Set', xTrain_cv.shape)
print('Shape of yTrain Set', yTrain_cv.shape)

print('')

print('Shape of xTest Set', xTest_cv.shape)
print('Shape of yTest Set', yTest_cv.shape)
# Out:
# Shape of xTrain Set (17762, 12)
# Shape of yTrain Set (17762, 1)
#
# Shape of xTest Set (1973, 12)
# Shape of yTest Set (1973, 1)

# %%
sns.countplot(df_final['Appliances_Energy'])
# Out:
# <AxesSubplot:xlabel='Appliances_Energy', ylabel='count'>

# %%
nbreClasses = 10
def rbf(x, c, s):
    distance = np.linalg.norm(np.array(x)-np.array(c))
    return 1 / np.exp(-distance / (2*s ** 2))

def kmeans(X, k, itersmax=100):
    # randomly select initial clusters from input data
    clusters = X[np.random.choice(range(len(X)), k, replace=False)]
    converged = False
    
    iter = 0
    while (not converged) and (iter < itersmax):
        cluster_list = [[] for i in range(len(clusters))]
        for x in X: # Pour chaque exemple
            distances = []
            for c in clusters:
                distances.append(np.linalg.norm(np.array(x)-np.array(c)))
            cluster_list[int(np.argmin(distances))].append(x)
        cluster_list = list((filter(None, cluster_list)))
        prevClusters = clusters.copy()
        clusters = []
        for j in range(len(cluster_list)):
            clusters.append(np.mean(cluster_list[j], axis=0))
        diff = np.abs(np.sum(prevClusters) - np.sum(clusters))
        print('Test KMEANS : ', diff)
        converged = (diff == 0)
        iter += 1
    stds = [np.std(x) for x in cluster_list]
    return np.array(clusters), stds

# %%
class RBFNet(object):
    
    def __init__(self, k=2, lr=0.01, epochs=100, rbf=rbf, withstds=True):
        self.k = k
        self.lr = lr
        self.epochs = epochs
        self.rbf = rbf
        self.withstds = withstds
 
        self.w = np.random.randn(k)
        self.b = np.random.randn(1)

    def fit(self, X, y):
        if self.withstds:
            # trouver les centres et leurs écart type
            self.centers, self.stds = kmeans(X, self.k)
        else:
            # écart type unique
            self.centers, _ = kmeans(X, self.k)
            dMax = max([np.abs(c1 - c2) for c1 in self.centers for c2 in self.centers])
            self.stds = np.repeat(dMax / np.sqrt(2*self.k), self.k)

        # Apprentissage
        epochsDisp = self.epochs//10
        
        for epoch in range(self.epochs):
            globalLoss=0.0;
            for i in range(X.shape[0]):
                # sens direct
                a = np.array([self.rbf(X[i], c, s) for c, s, in zip(self.centers, self.stds)])
                F = a.T.dot(self.w) + self.b

                loss = (y[i] - F).flatten() ** 2
                globalLoss = globalLoss + loss[0]
                # sens inverse
                error = -(y[i] - F).flatten()

                # Mise à jour
                self.w = self.w - self.lr * a * error
                self.b = self.b - self.lr * error
            
            if epoch%epochsDisp == 0 :
                    print(str(epoch),  'Loss: {0:.2f}'.format(globalLoss/X.shape[0]))
    
    def predict(self, X):
        y_pred = []
        for i in range(X.shape[0]):
            a = np.array([self.rbf(X[i], c, s) for c, s, in zip(self.centers, self.stds)])
            F = a.T.dot(self.w) + self.b
            y_pred.append(F)
        return np.array(y_pred)

# %%
#x = df_final.drop(columns=['Appliances_Energy'],axis=1)

#y = df_final[['Appliances_Energy']]

#xTrain, xTest, yTrain, yTest = train_test_split(x,y, test_size = 0.3, random_state = 0)
(train_x, test_x, train_y, test_y) = train_test_split(x, y, test_size=0.15)
train_y = LabelBinarizer().fit_transform(train_y)
test_y = LabelBinarizer().fit_transform(test_y)

# %%
rbfnet = RBFNet(lr=0.01, k=30, epochs=300, withstds='true')
rbfnet.fit(train_x, train_y)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_17788/1089820388.py in <module>
#       1 rbfnet = RBFNet(lr=0.01, k=30, epochs=20000, withstds='true')
# ----> 2 rbfnet.fit(train_x, train_y)
#
# ~\AppData\Local\Temp/ipykernel_17788/3140173947.py in fit(self, X, y)
#      14         if self.withstds:
#      15             # trouver les centres et leurs écart type
# ---> 16             self.centers, self.stds = kmeans(X, self.k)
#      17         else:
#      18             # écart type unique
#
# ~\AppData\Local\Temp/ipykernel_17788/2357718558.py in kmeans(X, k, itersmax)
#       6 def kmeans(X, k, itersmax=100):
#       7     # randomly select initial clusters from input data
# ----> 8     clusters = X[np.random.choice(range(len(X)), k, replace=False)]
#       9     converged = False
#      10
#
# ~\anaconda3\lib\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    3462             if is_iterator(key):
#    3463                 key = list(key)
# -> 3464             indexer = self.loc._get_listlike_indexer(key, axis=1)[1]
#    3465
#    3466         # take() does not accept boolean indexers
#
# ~\anaconda3\lib\site-packages\pandas\core\indexing.py in _get_listlike_indexer(self, key, axis)
#    1312             keyarr, indexer, new_indexer = ax._reindex_non_unique(keyarr)
#    1313
# -> 1314         self._validate_read_indexer(keyarr, indexer, axis)
#    1315
#    1316         if needs_i8_conversion(ax.dtype) or isinstance(
#
# ~\anaconda3\lib\site-packages\pandas\core\indexing.py in _validate_read_indexer(self, key, indexer, axis)
#    1372                 if use_interval_msg:
#    1373                     key = list(key)
# -> 1374                 raise KeyError(f"None of [{key}] are in the [{axis_name}]")
#    1375
#    1376             not_found = list(ensure_index(key)[missing_mask.nonzero()[0]].unique())
#
# KeyError: "None of [Int64Index([ 9972,  6886, 13583,  3519, 11552,  4070, 11623,  2357,  8607,\n             7787, 12492,  5634, 10370, 12862,  4889,  6507, 12683,  6804,\n             3043, 12061,   188, 10736, 13116,  3654, 15231,  7655,  1984,\n             1862, 10431,  2974],\n           dtype='int64')] are in the [columns]"

# %%
# Test pour un exemple
randIndex = np.random.randint(0,digits.data.shape[0]-1,1)[0]
randClass = np.int(digits.target[randIndex])
print(digits.data[randIndex].shape)
print('Exemple : '+str(randIndex)+', classe réelle : '+str(randClass))
print('Sorte prédite : \n'+str(rbfnet.predict(digits.data[randIndex].reshape(1,64)))+')' )

# %%
print('Evaluation : ')
print('Exemples Test :', test_x.shape)
predictions = rbfnet.predict(test_x)
predictions = predictions.argmax(axis=1) # Obtenir l'indice du chiffre
print(classification_report(test_y.argmax(axis=1), predictions)) # Rapport de classification
